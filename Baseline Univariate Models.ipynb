# %%
rm(list=ls())

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  576475 30.8 1250438    66.8 1110235  59.3
# Vcells 1078573  8.3 8388608    64.0 1820941  13.9

# %%
# install.packages("tidyverse") # sagemaker has
library(tidyverse)
# install.packages("parallel") # sagemaker has
library(parallel)
# install.packages("cluster") # sagemaker has
library(cluster)
install.packages("forecast") # sagemaker doesn't have
library(forecast)
install.packages("mclust") # sagemaker doesn't have
library(mclust)
install.packages("Metrics") # sagemaker doesn't have
library(Metrics)
install.packages("Rcatch22") # sagemaker doesn't have
library(Rcatch22)
install.packages("tseries") # sagemaker doesn't have
library(tseries)
install.packages("factoextra") # sagemaker doesn't have
library(factoextra)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# also installing the dependencies ‘quadprog’, ‘fracdiff’, ‘lmtest’, ‘tseries’, ‘urca’, ‘RcppArmadillo’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Package 'mclust' version 5.4.9
# Type 'citation("mclust")' for citing this R package in publications.
#
#
# Attaching package: ‘mclust’
#
#
# The following object is masked from ‘package:purrr’:
#
#     map
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
#
# Attaching package: ‘Metrics’
#
#
# The following object is masked from ‘package:forecast’:
#
#     accuracy
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# also installing the dependencies ‘SparseM’, ‘MatrixModels’, ‘sp’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘carData’, ‘pbkrtest’, ‘quantreg’, ‘maptools’, ‘lme4’, ‘crosstalk’, ‘corrplot’, ‘viridis’, ‘car’, ‘DT’, ‘ellipse’, ‘flashClust’, ‘leaps’, ‘scatterplot3d’, ‘ggsci’, ‘cowplot’, ‘ggsignif’, ‘gridExtra’, ‘polynom’, ‘rstatix’, ‘abind’, ‘dendextend’, ‘FactoMineR’, ‘ggpubr’, ‘ggrepel’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa

# %% [markdown]
# # Read In and Subset Data

# %%
# Read in all files from the Data/Processed directory
england_fnames <- list.files("Data/Processed/Highways_England/", pattern="*.csv", full.names=TRUE)
england_df_list <- lapply(england_fnames, read_csv)

portland_fnames <- list.files("Data/Processed/Portland/", pattern="*.csv", full.names=TRUE)
portland_df_list <- lapply(portland_fnames, read_csv)

utah_fnames <- list.files("Data/Processed/Utah/", pattern="*.csv", full.names=TRUE)
utah_df_list <- lapply(utah_fnames, read_csv)
# Out:
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 35040 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): site_name
# dbl  (5): day_of_week, day_of_year, interval_of_day, avg_mph, total_volume
# lgl  (2): missing_speed, missing_volume
# dttm (1): timestamp
# date (1): date
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
england_df_list <- lapply(england_df_list, function(x) x %>% arrange(timestamp))
portland_df_list <- lapply(portland_df_list, function(x) x %>% arrange(timestamp))
utah_df_list <- lapply(utah_df_list, function(x) x %>% arrange(timestamp))

# %%
total_df_list <- append(append(england_df_list, portland_df_list), utah_df_list)

# %%
set.seed(54321)
starting_points <- sample(1:((96*365)-(96*12*7)), 
                          length(total_df_list), 
                          replace=FALSE)
ending_points <- starting_points + (96*7*12) - 1

# %%
points_df <- data.frame(start=starting_points, end=ending_points)
write.csv(points_df, 'start_end_points.csv', row.names=FALSE)

# %%
total_df_list <- lapply(total_df_list, function(x) x %>% mutate(rn = row_number()))

# %%
total_df_list_samples <- lapply(1:length(total_df_list), 
                                function(x) total_df_list[[x]] %>% 
                                    filter(rn >= starting_points[x]) %>%
                                    filter(rn <= ending_points[x]))

# %%
total_df_list_samples <- lapply(total_df_list_samples, 
                                function(x) x %>% mutate(rn = row_number()) %>%
                                    mutate(train_val_test = ifelse(rn <= (96*7*8), 
                                                                   "train", 
                                                                   ifelse(rn <= (96*7*10), 
                                                                          "val", 
                                                                          "test")))
                                
                               )

# %%
train_val_samples <- lapply(total_df_list_samples, function(x) x %>% filter(train_val_test != "test"))

# %%
test_samples <- lapply(total_df_list_samples, function(x) x %>% filter(train_val_test == "test"))

# %%
train_val_samples_ts <- lapply(train_val_samples, 
                               function(x) msts(x$total_volume, seasonal.periods=c(24*4, 24*4*7)))

# %%
test_samples_ts <- lapply(test_samples,
                          function(x) msts(x$total_volume, seasonal.periods=c(24*4, 24*4*7)))

# %% [markdown]
# # ARIMA with Fourier Terms

# %%
arima_w_fourier <- function(ts_train, ts_test) {
    
    fourier_term_train <- fourier(ts_train, K=c(2,2))
    fourier_term_test <- fourier(ts_train, K=c(2,2), h=length(ts_test))
    
    arima_model <- auto.arima(ts_train, xreg = fourier_term_train, seasonal = FALSE)
#     train_rmse <- rmse(ts_train, fitted(arima_model))    
    
#     preds <- c()
#     ytest <- ts_test
#     xtest <- fourier_term_test
#     mod <- arima_model

#     for (idx in 1:length(ts_test)) {
#         pred <- forecast(mod, xreg=t(as.matrix(xtest[idx:idx,])))
#         preds <- c(preds, pred$mean[1])

#         mod <- Arima(y=ytest[idx], xreg=t(as.matrix(xtest[idx:idx,])), model=mod)
#     }

#     test_rmse <- rmse(ts_test, preds)
    
#     return_list=list('train_rmse'=train_rmse, 'test_rmse'=test_rmse)  
    
    arima_model
}

# %%
arima_res <- lapply(1:length(train_val_samples_ts), 
                    function(x) arima_w_fourier(train_val_samples_ts[[x]], test_samples_ts[[x]]))

# %%
head(arima_res)
# Out:
# [[1]]
# Series: ts_train
# Regression with ARIMA(5,0,2) errors
#
# Coefficients:
#          ar1      ar2     ar3     ar4      ar5      ma1     ma2  intercept
#       2.1629  -1.4528  0.1275  0.1893  -0.0571  -1.3374  0.6289   254.1495
# s.e.  0.0449   0.0758  0.0382  0.0368   0.0183   0.0430  0.0362     3.6324
#           S1-96     C1-96    S2-96     C2-96   S1-672   C1-672   S2-672
#       -116.5934  156.5264  39.4507  -64.8637  -7.8900  18.1517  16.6987
# s.e.     5.2674    5.2620   5.5492    5.5436   5.1423   5.1372   5.1504
#         C2-672
#       -24.4160
# s.e.    5.1453
#
# sigma^2 = 954.4:  log likelihood = -32581.97
# AIC=65197.94   AICc=65198.03   BIC=65313.75
#
# [[2]]
# Series: ts_train
# Regression with ARIMA(2,0,2) errors
#
# Coefficients:
#          ar1      ar2      ma1     ma2  intercept     S1-96     C1-96   S2-96
#       1.7889  -0.8335  -1.0928  0.3050   194.5906  152.7868  -27.9503  7.6994
# s.e.  0.0167   0.0145   0.0190  0.0141     1.6538    2.5016    2.5011  2.9966
#         C2-96    S1-672   C1-672  S2-672    C2-672
#       35.6481  -12.7397  -8.3027  3.3738  -20.9570
# s.e.   2.9952    2.3423   2.3420  2.3520    2.3517
#
# sigma^2 = 815.6:  log likelihood = -32054.64
# AIC=64137.28   AICc=64137.34   BIC=64232.66
#
# [[3]]
# Series: ts_train
# Regression with ARIMA(5,0,1) errors
#
# Coefficients:
#          ar1      ar2      ar3      ar4      ar5      ma1  intercept      S1-96
#       1.3672  -0.2826  -0.0365  -0.0304  -0.0800  -0.6719   203.7137  -176.3182
# s.e.  0.0341   0.0311   0.0220   0.0214   0.0149   0.0325     1.8567     2.8556
#         C1-96     S2-96    C2-96   S1-672   C1-672    S2-672   C2-672
#       63.3262  -28.5151  37.2941  24.1447  16.1943  -29.0253  -3.2202
# s.e.   2.8547    3.4877   3.4853   2.6306   2.6301    2.6444   2.6439
#
# sigma^2 = 838:  log likelihood = -32144.7
# AIC=64321.41   AICc=64321.49   BIC=64430.41
#
# [[4]]
# Series: ts_train
# Regression with ARIMA(2,0,2) errors
#
# Coefficients:
#          ar1     ar2      ma1     ma2  intercept     S1-96      C1-96    S2-96
#       1.7686  -0.815  -0.9105  0.2862   414.8726  183.0692  -304.6760  40.6741
# s.e.  0.0151   0.014   0.0178  0.0131     5.0162    7.4516     7.4465   8.4134
#           C2-96   S1-672    C1-672   S2-672    C2-672
#       -108.2788  10.2553  -35.0083  28.4225  -40.6005
# s.e.     8.4065   7.1034    7.0990   7.1252    7.1208
#
# sigma^2 = 2584:  log likelihood = -35930.39
# AIC=71888.77   AICc=71888.83   BIC=71984.15
#
# [[5]]
# Series: ts_train
# Regression with ARIMA(1,1,3) errors
#
# Coefficients:
#          ar1      ma1     ma2     ma3      S1-96     C1-96    S2-96    C2-96
#       0.4839  -0.6675  0.2339  0.0863  -347.2658  172.9365  16.7413  36.2973
# s.e.  0.0493   0.0502  0.0189  0.0169    14.8926   14.8950   7.2913   7.2923
#         S1-672    C1-672   S2-672   C2-672
#        34.5571  -23.7953  60.9504   8.1581
# s.e.  104.9751  104.9968  52.4654  52.4729
#
# sigma^2 = 2029:  log likelihood = -35111.45
# AIC=70248.91   AICc=70248.96   BIC=70337.47
#
# [[6]]
# Series: ts_train
# Regression with ARIMA(2,0,5) errors
#
# Coefficients:
#          ar1      ar2      ma1     ma2      ma3     ma4      ma5  intercept
#       1.7852  -0.8167  -1.0023  0.2506  -0.0145  0.0763  -0.0379   460.7551
# s.e.  0.0245   0.0217   0.0275  0.0175   0.0180  0.0175   0.0150     4.8030
#          S1-96     C1-96    S2-96    C2-96   S1-672   C1-672   S2-672   C2-672
#       -354.565  155.3995  16.8832  44.7943  -4.2424  42.8236  51.6351  36.8382
# s.e.     7.140    7.1325   7.5626   7.5545   6.8032   6.7968   6.8260   6.8195
#
# sigma^2 = 2082:  log likelihood = -35202.37
# AIC=70438.74   AICc=70438.83   BIC=70554.56

# %%
saveRDS(arima_res, file="auto_arima_models.RData")

# %%
arima_res <- readRDS("auto_arima_models.RData")

# %%
arima_w_fourier_predict <- function(ts_train, ts_test, model) {
    
    fourier_term_train <- fourier(ts_train, K=c(2,2))
    fourier_term_test <- fourier(ts_train, K=c(2,2), h=length(ts_test))

    train_preds <- fitted(model)
    
    train_rmse <- rmse(ts_train, train_preds)
    train_mae <- mae(ts_train, train_preds)
    
    mod_test <- Arima(y=c(ts_train, ts_test), 
                      xreg=rbind(fourier_term_train,
                                 fourier_term_test),
                      model=model)
    
    test_preds <- fitted(mod_test)[-c(1:length(ts_train))]
    
    test_rmse <- rmse(ts_test, test_preds)
    test_mae <- mae(ts_test, test_preds)
    
    return_list <- list("train_rmse"=train_rmse, "train_mae"=train_mae,
                        "test_rmse"=test_rmse, "test_mae"=test_mae, "raw_forecasts"=test_preds)
}

# %%
arima_perf <- lapply(1:length(test_samples_ts),
                     function(x) arima_w_fourier_predict(train_val_samples_ts[[x]],
                                                         test_samples_ts[[x]],
                                                         arima_res[[x]])
                    )

# %%
arima_raw_forecasts <- lapply(1:length(arima_perf), 
                              function(x) data.frame(forecast=arima_perf[[x]]$raw_forecasts, ts_index=x))

# %%
arima_raw_forecasts_df <- do.call("rbind", arima_raw_forecasts)

# %%
head(arima_raw_forecasts_df)
# Out:
#   forecast ts_index
# 1 319.2737 1
# 2 322.1082 1
# 3 336.3362 1
# 4 350.8188 1
# 5 348.5756 1
# 6 346.3648 1

# %%
nrow(arima_raw_forecasts_df)
# Out:
# [1] 102144

# %%
write.csv(arima_raw_forecasts_df, "arima_raw_forecasts.csv", row.names=FALSE)

# %%
arima_perf_df <- data.frame(train_rmse=unlist(lapply(arima_perf, function(x) x$train_rmse)),
                            train_mae=unlist(lapply(arima_perf, function(x) x$train_mae)),
                            test_rmse=unlist(lapply(arima_perf, function(x) x$test_rmse)),
                            test_mae=unlist(lapply(arima_perf, function(x) x$test_mae)))

# %%
write.csv(arima_perf_df, "auto_arima_performance.csv", row.names=FALSE)

# %%
saveRDS(arima_perf_df, file="auto_arima_performance.RData")

# %%
arima_results <- readRDS("auto_arima_performance.RData")

# %%
mean(arima_results$test_rmse)
# Out:
# [1] 35.72201

# %%
mean(arima_results$test_mae)
# Out:
# [1] 24.28929

# %% [markdown]
# # Naive Forecasts

# %%
naive_forec <- function(train_ts, test_ts, lag=1) {
    train_forec <- lag(train_ts, lag)
        
    train_rmse <- rmse(train_ts[-c(1:lag)], train_forec[-c(1:lag)])
    train_mae <- mae(train_ts[-c(1:lag)], train_forec[-c(1:lag)])
    
    n <- length(train_ts)
    n1 <- n-(lag-1)
    train_test_data <- c(train_ts[n1:n], test_ts)
    
    test_forec <- lag(train_test_data, lag)
    test_forec_final <- test_forec[-c(1:lag)]
        
    test_rmse <- rmse(test_ts, test_forec_final)
    test_mae <- mae(test_ts, test_forec_final)
        
    return_list <- list("train_rmse"=train_rmse, "train_mae"=train_mae,
                        "test_rmse"=test_rmse, "test_mae"=test_mae, "raw_forecasts"=test_forec_final) 

}

# %% [markdown]
# ## Simple Naive Forecast

# %%
simple_naive_forecasts <- lapply(1:length(train_val_samples),
                                 function(x) naive_forec(train_val_samples[[x]]$total_volume,
                                                         test_samples[[x]]$total_volume))

# %%
mean(unlist(lapply(simple_naive_forecasts, function(x) x$test_rmse)))
# Out:
# [1] 39.77066

# %%
mean(unlist(lapply(simple_naive_forecasts, function(x) x$test_mae)))
# Out:
# [1] 26.66599

# %%
simple_naive_raw_forecasts <- lapply(1:length(simple_naive_forecasts), 
                                     function(x) data.frame(forecast=simple_naive_forecasts[[x]]$raw_forecasts, 
                                                            ts_index=x))

# %%
simple_naive_raw_forecasts_df <- do.call("rbind", simple_naive_raw_forecasts)

# %%
write.csv(simple_naive_raw_forecasts_df, "simple_naive_raw_forecasts.csv", row.names=FALSE)

# %% [markdown]
# ## Daily Seasonal Naive Forecast

# %%
daily_naive_forecasts <- lapply(1:length(train_val_samples),
                                function(x) naive_forec(train_val_samples[[x]]$total_volume,
                                                        test_samples[[x]]$total_volume,
                                                        lag=96
                                                       )
                                )

# %%
mean(unlist(lapply(daily_naive_forecasts, function(x) x$test_rmse)))
# Out:
# [1] 89.42218

# %%
mean(unlist(lapply(daily_naive_forecasts, function(x) x$test_mae)))
# Out:
# [1] 54.66551

# %%
daily_naive_raw_forecasts <- lapply(1:length(daily_naive_forecasts), 
                                     function(x) data.frame(forecast=daily_naive_forecasts[[x]]$raw_forecasts, 
                                                            ts_index=x))

# %%
daily_naive_raw_forecasts_df <- do.call("rbind", daily_naive_raw_forecasts)

# %%
write.csv(daily_naive_raw_forecasts_df, "daily_naive_raw_forecasts.csv", row.names=FALSE)

# %% [markdown]
# ## Weekly Naive Forecast

# %%
weekly_naive_forecasts <- lapply(1:length(train_val_samples),
                                 function(x) naive_forec(train_val_samples[[x]]$total_volume,
                                                         test_samples[[x]]$total_volume,
                                                         lag=672
                                                       )
                                )

# %%
mean(unlist(lapply(weekly_naive_forecasts, function(x) x$test_rmse)))
# Out:
# [1] 60.71589

# %%
mean(unlist(lapply(weekly_naive_forecasts, function(x) x$test_mae)))
# Out:
# [1] 37.37687

# %%
weekly_naive_raw_forecasts <- lapply(1:length(weekly_naive_forecasts), 
                                     function(x) data.frame(forecast=weekly_naive_forecasts[[x]]$raw_forecasts, 
                                                            ts_index=x))

# %%
weekly_naive_raw_forecasts_df <- do.call("rbind", weekly_naive_raw_forecasts)

# %%
write.csv(weekly_naive_raw_forecasts_df, "weekly_naive_raw_forecasts.csv", row.names=FALSE)

# %% [markdown]
# ## Save Performance Measures to CSV

# %%
naive_perf_df <- data.frame(simple_naive_train_rmse=unlist(lapply(simple_naive_forecasts, function(x) x$train_rmse)),
                            simple_naive_train_mae=unlist(lapply(simple_naive_forecasts, function(x) x$train_mae)),
                            simple_naive_test_rmse=unlist(lapply(simple_naive_forecasts, function(x) x$test_rmse)),
                            simple_naive_test_mae=unlist(lapply(simple_naive_forecasts, function(x) x$test_mae)),
                            daily_naive_train_rmse=unlist(lapply(daily_naive_forecasts, function(x) x$train_rmse)),
                            daily_naive_train_mae=unlist(lapply(daily_naive_forecasts, function(x) x$train_mae)),
                            daily_naive_test_rmse=unlist(lapply(daily_naive_forecasts, function(x) x$test_rmse)),
                            daily_naive_test_mae=unlist(lapply(daily_naive_forecasts, function(x) x$test_mae)),
                            weekly_naive_train_rmse=unlist(lapply(weekly_naive_forecasts, function(x) x$train_rmse)),
                            weekly_naive_train_mae=unlist(lapply(weekly_naive_forecasts, function(x) x$train_mae)),
                            weekly_naive_test_rmse=unlist(lapply(weekly_naive_forecasts, function(x) x$test_rmse)),
                            weekly_naive_test_mae=unlist(lapply(weekly_naive_forecasts, function(x) x$test_mae)))

# %%
write.csv(naive_perf_df, "naive_models_performance.csv", row.names=FALSE)
